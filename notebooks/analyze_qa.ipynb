# %%
env(mpl=True)
if sys.path[0] != '..':
    sys.path.insert(0, '..')
import common

# %%
qa = unpickle('../data/qa/train.pkl')
vocab = unpickle('../data/qa/vocab.pkl')

# %%
qa_toks = [q.split(' ') for q in qa]

# %%
qlens = np.array([len(toks) for toks in qa_toks])

# %%
plt.hist(qlens, bins=50);

# %%
vocab_toks, vocab_counts = zip(*vocab.tok_counts)
vocab_counts = np.array(vocab_counts)

# %%
vocab_counts[((vocab_counts.cumsum() / vocab_counts.sum()) > 0.95).nonzero()[0][0]]
# Out:
# 18

# %%
cutoff = (vocab_counts < 20).nonzero()[0][0]
cutoff
# Out:
# 11054

# %%
# plt.semilogy(vocab_counts[vocab_count ]);
vocab_counts[10000]
# Out:
# 23
